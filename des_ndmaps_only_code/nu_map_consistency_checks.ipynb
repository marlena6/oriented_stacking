# %%
import healpy as hp

# %%
numap_bin4 = hp.read_map("/mnt/raid-cita/mlokken/data/number_density_maps/maglim/numap_25_z_0pt36_0pt53.fits")

# %%
hp.mollview(numap_bin4, max=5)

# %%
hp.cartview(numap_bin4, max=.05, lonra=[0,60], latra=[-20,10])

# %%
import numpy as np

# %%
np.sum(numap_bin4)
# Out:
# 1.022530504712904e-09
