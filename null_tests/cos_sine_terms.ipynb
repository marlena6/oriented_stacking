# %%
from astropy.io import fits
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
cardstack = "/mnt/scratch-lustre/mlokken/stacking/Cardinal_paper2/orient_by_maglim_75/stacks/0/Cardinal_maglim_z_0pt36_0pt53_redmapper_lambdagt20_1493_1593Mpc_nugt2_egtpt3_20pt0_orientXYUP_75pct_maglim_1443_1643Mpc_reg0_stk.fits"

# %%
with fits.open(cardstack) as hdu:
    data = hdu[0].data

# %%
plt.imshow(data)

# %%
dat
